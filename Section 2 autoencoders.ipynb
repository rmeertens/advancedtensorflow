# %% [markdown]
# # Section 2: autoencoders

# %% [markdown]
# An autoencoder is a neural network that learns to represent data in a space that requires less space. You can see it as a data-compression algorithm, where a neural network learns to compress and decompress the data.
#
# An autoencoder often consists of (several) **encoding** layers, and (several) **decoding** layers.
#
# ![Autoencoder structure](https://upload.wikimedia.org/wikipedia/commons/2/28/Autoencoder_structure.png)

# %% [markdown]
# The center layer, which has the smallest amount of neurons, is referred to as the **code**, or **latent representation**. We don't directly observe the values here, but we can use them later for other representations.
#
# ### Encoding MNIST characters
# Let's dive directly into autoencoders and make a very simple one ourselves. If you followed my previous course, or any other machine learnign course, you are familiar with the MNIST dataset. This dataset consists of images of characters that are 28 by 28 pixels. A function to load the MNIST dataset is included in the TensorFlow library. When you use this each character is represented as vector of 28*28 = 784 pixels.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.contrib.slim import fully_connected as fc
import matplotlib.pyplot as plt 

from tensorflow.examples.tutorials.mnist import input_data

# %matplotlib inline

mnist = input_data.read_data_sets('datasets/MNIST_data', one_hot=True)
input_dim = mnist.train.images[0].shape[0]
print(input_dim)
h_image=28
w_image=28
# Out:
# Extracting datasets/MNIST_data/train-images-idx3-ubyte.gz
# Extracting datasets/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting datasets/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting datasets/MNIST_data/t10k-labels-idx1-ubyte.gz
# 784

# %% [markdown]
# Let's start with the simplest way of an autoencoder: only using dense/fully connected layers. Note that you can use convolutional layers in an autoencoder, but right now we keep everything as simple as possible to show how effective an autoencoder can be even when not optimizing everything.

# %%
batch_size = 128
latent_first_size = 512
latent_middle_size = 10

input_placeholder = tf.placeholder(dtype=tf.float32, 
                                   shape=[None, input_dim],
                                  name='inputplaceholder')
## Encode step: 
fc1 = tf.layers.dense(input_placeholder, 
                      latent_first_size, 
                     activation = tf.nn.relu)
latent_encoded = tf.layers.dense(fc1, 
                                 latent_middle_size, 
                                activation = tf.nn.relu)
print(latent_encoded)
# Out:
# Tensor("dense_2/Relu:0", shape=(?, 10), dtype=float32)

# %% [markdown]
# ### Decoding
# We now built the first part of the neural network: the encoder. It's difficult to train only this part of the neural network, as it's difficult to evaluate how well information is encoded without knowing how to decode it. This is why we immediately add the next part of the neural network: the decoder.

# %%
## Decode step
decoded_1 = tf.layers.dense(latent_encoded, 
                            latent_first_size,
                           activation = tf.nn.relu)
result_decoder = tf.layers.dense(decoded_1, 
                                 input_dim, activation=tf.nn.sigmoid)

# %% [markdown]
# ### Evaluating performance
# We now made our decoder. The next question is: how do we measure how well our neural network is performing, and what loss function do we use? There are multiple ways to evaluate it we will use either:
# - A very simple metric: the mean squared error. We take the MSE between the input placeholder, and the result of our decoder.
# - A [cross entropy](https://en.wikipedia.org/wiki/Cross_entropy) loss. Due to the nature of the log function the loss tends to be higher, and the network might perform better.
#
# Try to toy around with these loss functions, and discover what functions work for you, and which ones
# do not work for you...

# %%
## MEAN SQUARED ERROR LOSS:
# reconstruction_loss = tf.losses.mean_squared_error(input_placeholder, 
#                                                    result_decoder)

## CROSS ENTROPY LOSS:
epsilon = 1e-10
reconstruction_loss = -tf.reduce_sum(
    input_placeholder * tf.log(epsilon+result_decoder) + (1-input_placeholder) * tf.log(epsilon+1-result_decoder), 
    axis=1)
reconstruction_loss = tf.reduce_mean(reconstruction_loss)

## ADAM OPTIMIZER
trainstep = tf.train.AdamOptimizer().minimize(reconstruction_loss)

# %% [markdown]
# ### Training
# Now training is simple: feed a lot of MNIST character through the autoencoder and verify that it's learning something!

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

iterations = 1000
loss_history = list()
for iteration in range(iterations):
    batch = mnist.train.next_batch(batch_size)
    _, loss = sess.run([trainstep, reconstruction_loss],
                                feed_dict={input_placeholder: batch[0]})
    loss_history.append(loss)

plt.plot(loss_history[20:])
plt.show()
no_do_loss_history = loss_history

# %% [markdown]
# ## Video 2: practical application: denoising

# %% [markdown]
# Autoencoders are really useful tools, although in practice they are not used a lot. In this section we will discuss several applications of autoencoders. One such application is using an autoencoder to remove noise from an image.
#
# Let's first see how we can use an autoencoder in practice to encode and decode images:

# %%
batch = mnist.test.next_batch(10)
decoded = sess.run(result_decoder,
                    feed_dict={input_placeholder: batch[0]})

for digit in decoded:
    reshaped = np.reshape(digit, (h_image,w_image))
    plt.imshow(reshaped)
    plt.show()

# %% [markdown]
# ### Adding noise
# Now that we know that our autoencoder is working we can crate a whole new noisy MNIST dataset:

# %%
batch = mnist.test.next_batch(10)
noisy_batch = list()
std_noise = 0.1

for digit in batch[0]:
    ## Add noise to the digit
    noise = np.random.normal(0,std_noise,input_dim)
    noisy_digit = digit + noise
    noisy_digit = np.clip(noisy_digit, 0, 1)

    ## Add it to our evaluation set
    noisy_batch.append(noisy_digit)

    ## Visualise the digit
    reshaped_digit = np.reshape(noisy_digit, (h_image,w_image))
    plt.imshow(reshaped_digit)
    plt.show()

# %% [markdown]
# Without any additional training, and without optimizing our network, without even using convolutional methods, and using only a few layers, we can throw this in our network and get "denoised" characters as output:

# %%
  
decoded = sess.run(result_decoder,feed_dict={input_placeholder: noisy_batch})
for index, digit in enumerate(decoded):
    reshaped = np.reshape(digit, (h_image,w_image))
    #reshaped = np.clip(reshaped, 0.0, 1.0)
    
    reshaped_original = np.reshape(noisy_batch[index], (h_image,w_image))
    plt.imshow(reshaped_original)
    plt.show()
    plt.imshow(reshaped)
    plt.show()
print(noise.shape)
# Out:
# (784,)

# %% [markdown]
# ### Evaluation
# Now these denoised images are not of really high quality. One thing to note is that there is a bias after every layer. This bias tends to add things that are common for certain pixels to these pixels. This is the reason a seven might turn into a nine (there are often pixels to the left). Using other methods, such as convolutional layers to encode and decode, can really improve your autoencoder.

# %% [markdown]
# ## Video 4: variational autoencoder

# %% [markdown]
# There is a really good blog about variational autoencoders. Please [take a look at it](http://kvfrans.com/variational-autoencoders-explained/).
# You can even use an autoencoder to generate new images. By feeding values in the middle of your network your network will generate a new image. However: we don't know what range of values we can feed, and what this will result in.
#
# Although you can already do that right now, you get the best results using a so-called variational autoencoder. In that case we add an additional constraint to our neural network: the center layer has to follow a so-called "unit gaussian distribution". After we did this we can simply sample values from the same distribution, and we know this will result in a good looking image!
#
#
# Great explanation of Kullback Leibler divergence using space worms analogy: https://www.countbayesie.com/blog/2017/5/9/kullback-leibler-divergence-explained

# %%
latent_middle_size = 2

# %%
tf.reset_default_graph()

input_placeholder = tf.placeholder(dtype=tf.float32, 
                                   shape=[None, input_dim],
                                  name='inputplaceholder')
## Encode step: 
fc1 = tf.layers.dense(input_placeholder, 
                      latent_first_size, 
                     activation = tf.nn.elu)


# Z part
z_mu = tf.layers.dense(fc1, latent_middle_size, activation = None)
z_log_sigma_sq = tf.layers.dense(fc1, latent_middle_size, activation=None)

eps = tf.random_normal(shape=tf.shape(z_log_sigma_sq),mean=0, stddev=1, dtype=tf.float32)
#z = z_mu + (z_log_sigma_sq * eps)#tf.sqrt(tf.exp(z_log_sigma_sq)) * eps
z = z_mu + tf.sqrt(tf.exp(z_log_sigma_sq)) * eps

decoded_1 = tf.layers.dense(z, 
                            latent_first_size,
                           activation = tf.nn.elu)

result_decoder = tf.layers.dense(decoded_1, input_dim, activation = tf.nn.sigmoid)

## CROSS ENTROPY LOSS FOR THE RECONSTRUCTION
epsilon = 1e-10
reconstruction_loss = -tf.reduce_sum(
    input_placeholder * tf.log(epsilon+result_decoder) + (1-input_placeholder) * tf.log(epsilon+1-result_decoder), 
    axis=1
)
reconstruction_loss = tf.reduce_mean(reconstruction_loss)

## LOSS FOR THE LATENT SPACE
latent_loss = -0.5 * tf.reduce_sum(1 + z_log_sigma_sq - tf.square(z_mu) 
                                   - tf.exp(z_log_sigma_sq), axis=1)
latent_loss = tf.reduce_mean(latent_loss)

## TOTAL LOSS = COMBINED RECONSTRUCTION AND LATENT LOSS
total_loss = reconstruction_loss + latent_loss

trainstep = tf.train.AdamOptimizer().minimize(total_loss)

#trainstep = tf.train.GradientDescentOptimizer(0.05).minimize(total_loss)

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

iterations = 13000
loss_history = list()
for iteration in range(iterations):
    batch = mnist.train.next_batch(batch_size)
    _, loss, la = sess.run([trainstep, reconstruction_loss, latent_loss],
                                feed_dict={input_placeholder: batch[0]})
    if iteration % 100 == 0:
        print("reconstruction: " + str(loss) + " latent: " + str(la))
    loss_history.append(loss)
plt.plot(loss_history[20:])
plt.show()
# Out:
# reconstruction: 544.122 latent: 0.365358
# reconstruction: 187.172 latent: 7.76384
# reconstruction: 182.888 latent: 6.53988
# reconstruction: 180.504 latent: 5.70349
# reconstruction: 180.425 latent: 5.29008
# reconstruction: 174.124 latent: 5.16375
# reconstruction: 171.625 latent: 4.56985
# reconstruction: 166.218 latent: 4.90248
# reconstruction: 174.316 latent: 4.94121
# reconstruction: 174.665 latent: 4.77587
# reconstruction: 175.895 latent: 4.98164
# reconstruction: 168.711 latent: 5.01987
# reconstruction: 167.793 latent: 5.03084
# reconstruction: 168.839 latent: 4.90651
# reconstruction: 168.139 latent: 4.93767
# reconstruction: 169.739 latent: 4.79543
# reconstruction: 173.398 latent: 4.72624
# reconstruction: 162.072 latent: 4.58479
# reconstruction: 161.637 latent: 5.02052
# reconstruction: 158.129 latent: 5.05447
# reconstruction: 167.675 latent: 4.4118
# reconstruction: 163.078 latent: 4.62649
# reconstruction: 157.313 latent: 5.06315
# reconstruction: 164.861 latent: 4.61587
# reconstruction: 157.653 latent: 4.79331
# reconstruction: 165.813 latent: 4.6062
# reconstruction: 158.323 latent: 4.56315
# reconstruction: 159.828 latent: 5.24776
# reconstruction: 165.664 latent: 4.75118
# reconstruction: 169.651 latent: 4.5662
# reconstruction: 154.398 latent: 5.15618
# reconstruction: 162.949 latent: 4.81485
# reconstruction: 151.901 latent: 5.02847
# reconstruction: 161.534 latent: 4.98397
# reconstruction: 159.015 latent: 4.74454
# reconstruction: 159.375 latent: 4.75965
# reconstruction: 163.418 latent: 4.76578
# reconstruction: 169.527 latent: 4.92441
# reconstruction: 153.729 latent: 4.98166
# reconstruction: 161.348 latent: 4.51288
# reconstruction: 163.495 latent: 4.89207
# reconstruction: 155.725 latent: 5.11851
# reconstruction: 160.395 latent: 5.10363
# reconstruction: 161.381 latent: 5.03924
# reconstruction: 160.643 latent: 5.12083
# reconstruction: 167.526 latent: 4.80824
# reconstruction: 162.131 latent: 4.99518
# reconstruction: 161.116 latent: 4.91734
# reconstruction: 162.675 latent: 5.07451
# reconstruction: 163.185 latent: 5.12771
# reconstruction: 162.725 latent: 4.98345
# reconstruction: 155.696 latent: 5.17974
# reconstruction: 167.425 latent: 4.99123
# reconstruction: 162.35 latent: 4.88203
# reconstruction: 163.412 latent: 4.96337
# reconstruction: 160.875 latent: 5.25671
# reconstruction: 156.369 latent: 5.01344
# reconstruction: 162.271 latent: 5.02668
# reconstruction: 165.128 latent: 5.02033
# reconstruction: 157.064 latent: 4.92735
# reconstruction: 162.131 latent: 5.1218
# reconstruction: 151.039 latent: 5.45597
# reconstruction: 152.854 latent: 5.38292
# reconstruction: 159.152 latent: 5.41397
# reconstruction: 158.613 latent: 5.22021
# reconstruction: 160.096 latent: 5.32133
# reconstruction: 152.284 latent: 5.40935
# reconstruction: 160.324 latent: 5.02281
# reconstruction: 153.77 latent: 5.41025
# reconstruction: 160.078 latent: 5.59684
# reconstruction: 162.162 latent: 4.97398
# reconstruction: 163.483 latent: 5.4839
# reconstruction: 153.534 latent: 5.80675
# reconstruction: 150.075 latent: 5.57829
# reconstruction: 147.741 latent: 5.347
# reconstruction: 154.902 latent: 5.16933
# reconstruction: 156.785 latent: 5.10327
# reconstruction: 160.376 latent: 4.96175
# reconstruction: 160.263 latent: 4.9459
# reconstruction: 159.74 latent: 5.3761
# reconstruction: 155.567 latent: 5.22761
# reconstruction: 152.587 latent: 5.0479
# reconstruction: 152.362 latent: 5.59701
# reconstruction: 158.394 latent: 4.89587
# reconstruction: 158.193 latent: 5.40636
# reconstruction: 144.383 latent: 5.68064
# reconstruction: 156.663 latent: 5.81452
# reconstruction: 164.179 latent: 5.09661
# reconstruction: 165.242 latent: 5.09782
# reconstruction: 155.062 latent: 5.11554
# reconstruction: 154.447 latent: 5.61506
# reconstruction: 152.331 latent: 5.39915
# reconstruction: 146.111 latent: 5.406
# reconstruction: 154.893 latent: 5.07858
# reconstruction: 155.532 latent: 5.51929
# reconstruction: 161.461 latent: 5.11165
# reconstruction: 145.865 latent: 5.39321
# reconstruction: 152.497 latent: 5.62575
# reconstruction: 155.259 latent: 5.44677
# reconstruction: 150.401 latent: 5.47203
# reconstruction: 164.965 latent: 5.50308
# reconstruction: 153.31 latent: 5.64435
# reconstruction: 149.294 latent: 5.33753
# reconstruction: 158.547 latent: 5.27471
# reconstruction: 151.816 latent: 5.51887
# reconstruction: 156.024 latent: 5.21226
# reconstruction: 154.641 latent: 5.23159
# reconstruction: 151.625 latent: 5.71079
# reconstruction: 151.956 latent: 5.60009
# reconstruction: 155.395 latent: 5.70434
# reconstruction: 149.272 latent: 5.8219
# reconstruction: 149.537 latent: 5.52258
# reconstruction: 161.375 latent: 5.29176
# reconstruction: 158.499 latent: 5.17798
# reconstruction: 151.473 latent: 5.69871
# reconstruction: 154.893 latent: 5.32303
# reconstruction: 145.058 latent: 5.41693
# reconstruction: 144.377 latent: 5.92264
# reconstruction: 152.439 latent: 5.63173
# reconstruction: 148.11 latent: 5.82582
# reconstruction: 150.682 latent: 5.37185
# reconstruction: 154.453 latent: 5.56821
# reconstruction: 153.757 latent: 5.53771
# reconstruction: 146.108 latent: 5.55547
# reconstruction: 150.963 latent: 5.59637
# reconstruction: 159.617 latent: 5.25409
# reconstruction: 160.665 latent: 5.58201
# reconstruction: 158.504 latent: 5.29804
# reconstruction: 142.898 latent: 5.65431
# reconstruction: 149.075 latent: 5.37508

# %%
test_batch_size=10
generate_z = np.random.normal(size=[test_batch_size, latent_middle_size])
generated_digits = sess.run(result_decoder, feed_dict={z:generate_z})

for digit in generated_digits:
    digit = np.reshape(digit, (h_image,w_image))
    plt.imshow(digit)
    plt.show()

# %% [markdown]
# We can even plot these images in a grid to see the variety of generated images:

# %%
test_batch_size=128
generate_z = np.random.normal(size=[test_batch_size, latent_middle_size])
x_generated = sess.run(result_decoder, feed_dict={z:generate_z})


n = np.sqrt(test_batch_size).astype(np.int32)

I_generated = np.empty((h_image*n, w_image*n))

for i in range(n):
    for j in range(n):
        I_generated[i*h_image:(i+1)*h_image, j*w_image:(j+1)*w_image] = x_generated[i*n+j, :].reshape(h_image,w_image)

plt.figure(figsize=(8, 8))
plt.imshow(I_generated, cmap='gray')
